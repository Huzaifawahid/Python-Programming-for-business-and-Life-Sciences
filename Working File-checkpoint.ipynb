# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r"D:\SRM\Python Programming\MGT001437_ProjectA\store.csv")
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_20236\2952216386.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"D:\SRM\Python Programming\MGT001437_ProjectA\Merged_data.csv")

# %%
df
# Out:
#          Store        Date      Day  DayOfWeek  Open StoreType Assortment  \
# 0            1  2015-07-31   Friday          5     1         c          a
# 1            2  2015-07-31   Friday          5     1         a          a
# 2            3  2015-07-31   Friday          5     1         a          a
# 3            4  2015-07-31   Friday          5     1         c          c
# 4            5  2015-07-31   Friday          5     1         a          a
# ...        ...         ...      ...        ...   ...       ...        ...
# 1017204   1111  2013-01-01  Tuesday          2     0         a          a
# 1017205   1112  2013-01-01  Tuesday          2     0         c          c
# 1017206   1113  2013-01-01  Tuesday          2     0         a          c
# 1017207   1114  2013-01-01  Tuesday          2     0         a          c
# 1017208   1115  2013-01-01  Tuesday          2     0         d          c
#
#          Sales  Customers  Promo StateHoliday  SchoolHoliday  \
# ...

# %%
bol1= (df["Open"]==0) & (df["StateHoliday"]==0) & (df["SchoolHoliday"]==0)

# %%
Nonholiday_closure = df[bol1]

# %%
Nonholiday_closure
# Out:
#         Store        Date        Day  DayOfWeek  Open StoreType Assortment  \
# 5575        1  2015-07-26     Sunday          7     0         c          a
# 5576        2  2015-07-26     Sunday          7     0         a          a
# 5577        3  2015-07-26     Sunday          7     0         a          a
# 5578        4  2015-07-26     Sunday          7     0         c          c
# 5579        5  2015-07-26     Sunday          7     0         a          a
# ...       ...         ...        ...        ...   ...       ...        ...
# 982498    969  2013-01-02  Wednesday          5     0         a          c
# 982610   1081  2013-01-02  Wednesday          5     0         b          a
# 982747    103  2013-01-31   Thursday          4     0         d          c
# 982903    259  2013-01-31   Thursday          4     0         b          b
# 982993    349  2013-01-31   Thursday          4     0         c          c
#
#         Sales  Customers  Promo StateHoliday  SchoolHoliday  \
# ...

# %%
Nonholiday_closure.describe()
# Out:
#               Store     DayOfWeek     Open    Sales  Customers         Promo  \
# count  53634.000000  53634.000000  53634.0  53634.0    53634.0  53634.000000
# mean     553.218257      6.956651      0.0      0.0        0.0      0.004978
# std      321.971306      0.449949      0.0      0.0        0.0      0.070381
# min        1.000000      1.000000      0.0      0.0        0.0      0.000000
# 25%      274.000000      7.000000      0.0      0.0        0.0      0.000000
# 50%      552.500000      7.000000      0.0      0.0        0.0      0.000000
# 75%      832.000000      7.000000      0.0      0.0        0.0      0.000000
# max     1115.000000      7.000000      0.0      0.0        0.0      1.000000
#
#        SchoolHoliday  CompetitionDistance  CompetitionOpenSinceMonth  \
# count        53634.0         53490.000000               36857.000000
# mean             0.0          5349.632829                   7.223214
# ...

# %%
Nonholiday_closure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53634 entries, 5575 to 982993
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      53634 non-null  int64
#  1   Date                       53634 non-null  object
#  2   Day                        53634 non-null  object
#  3   DayOfWeek                  53634 non-null  int64
#  4   Open                       53634 non-null  int64
#  5   StoreType                  53634 non-null  object
#  6   Assortment                 53634 non-null  object
#  7   Sales                      53634 non-null  int64
#  8   Customers                  53634 non-null  int64
#  9   Promo                      53634 non-null  int64
#  10  StateHoliday               53634 non-null  object
#  11  SchoolHoliday              53634 non-null  int64
#  12  CompetitionDistance        53490 non-null  float64
# ...

# %%
Nonholiday_closure["Day"].value_counts()
# Out:
# Sunday       35349
# Wednesday     6064
# Saturday      4204
# Monday        3424
# Friday        2248
# Tuesday       1176
# Thursday      1169
# Name: Day, dtype: int64

# %%
Store_open_data= df[df["Open"]>=1]

# %%
Store_open_data
# Out:
#          Store        Date      Day  DayOfWeek  Open StoreType Assortment  \
# 0            1  2015-07-31   Friday          5     1         c          a
# 1            2  2015-07-31   Friday          5     1         a          a
# 2            3  2015-07-31   Friday          5     1         a          a
# 3            4  2015-07-31   Friday          5     1         c          c
# 4            5  2015-07-31   Friday          5     1         a          a
# ...        ...         ...      ...        ...   ...       ...        ...
# 1016776    682  2013-01-01  Tuesday          2     1         b          a
# 1016827    733  2013-01-01  Tuesday          2     1         b          b
# 1016863    769  2013-01-01  Tuesday          2     1         b          b
# 1017042    948  2013-01-01  Tuesday          2     1         b          b
# 1017190   1097  2013-01-01  Tuesday          2     1         b          b
#
#          Sales  Customers  Promo StateHoliday  SchoolHoliday  \
# ...

# %%
Store_open_data.describe()
# Out:
#                Store      DayOfWeek      Open          Sales      Customers  \
# count  844392.000000  844392.000000  844392.0  844392.000000  844392.000000
# mean      558.422920       3.520361       1.0    6955.514291     762.728395
# std       321.731914       1.723689       0.0    3104.214680     401.227674
# min         1.000000       1.000000       1.0       0.000000       0.000000
# 25%       280.000000       2.000000       1.0    4859.000000     519.000000
# 50%       558.000000       3.000000       1.0    6369.000000     676.000000
# 75%       837.000000       5.000000       1.0    8360.000000     893.000000
# max      1115.000000       7.000000       1.0   41551.000000    7388.000000
#
#                Promo  SchoolHoliday  CompetitionDistance  \
# count  844392.000000  844392.000000        842206.000000
# mean        0.446352       0.193580          5457.979627
# std         0.497114       0.395103          7809.437311
# ...

# %%
Store_close_data= df[df["Open"]==0]
Store_close_data
# Out:
#          Store        Date        Day  DayOfWeek  Open StoreType Assortment  \
# 291        292  2015-07-31     Friday          5     0         a          a
# 875        876  2015-07-31     Friday          5     0         a          a
# 1406       292  2015-07-30   Thursday          4     0         a          a
# 1990       876  2015-07-30   Thursday          4     0         a          a
# 2521       292  2015-07-29  Wednesday          3     0         a          a
# ...        ...         ...        ...        ...   ...       ...        ...
# 1017204   1111  2013-01-01    Tuesday          2     0         a          a
# 1017205   1112  2013-01-01    Tuesday          2     0         c          c
# 1017206   1113  2013-01-01    Tuesday          2     0         a          c
# 1017207   1114  2013-01-01    Tuesday          2     0         a          c
# 1017208   1115  2013-01-01    Tuesday          2     0         d          c
#
# ...

# %%
christmas_data = df[(df["Open"]>=1) & (df["StateHoliday"]== "c")]

# %%
christmas_data
# Out:
#         Store        Date        Day  DayOfWeek  Open StoreType Assortment  \
# 241126     85  2014-12-26     Friday          5     1         b          a
# 241267    259  2014-12-26     Friday          5     1         b          b
# 241270    262  2014-12-26     Friday          5     1         b          a
# 241281    274  2014-12-26     Friday          5     1         b          b
# 241298    299  2014-12-26     Friday          5     1         d          c
# ...       ...         ...        ...        ...   ...       ...        ...
# 617657    733  2013-12-25  Wednesday          3     1         b          b
# 617693    769  2013-12-25  Wednesday          3     1         b          b
# 617872    948  2013-12-25  Wednesday          3     1         b          b
# 618005   1081  2013-12-25  Wednesday          3     1         b          a
# 618021   1097  2013-12-25  Wednesday          3     1         b          b
#
#         Sales  Customers  Promo StateHoliday  SchoolHoliday  \
# ...

# %%
Easter_data = df[(df["Open"]>=1) & (df["StateHoliday"]== "b")]

# %%
Publicholiday_data = df[(df["Open"]>=1) & (df["StateHoliday"]== "a")]

# %%
noholiday_data = df[(df["Open"]>=1) & (df["StateHoliday"]== "0")]
